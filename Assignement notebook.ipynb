# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Mikael Björkqvist**
# Junior software developer

# %% [markdown]
# _I am interested in data science because it is one of most important professions of the future._

# %% [markdown]
# ### Code below is meant to calculate and print sum of X and Y variables

# %%
x=1
y=1
print(x+y)
# Out:
# 2

# %% [markdown]
# ~~strikethrough~~
#
# [Google link](https://www.google.com)
#
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "You pointed")
# ***
# | im  |a   |table   |
# |:-:|:-:|:-:|
# |1   |2   |3   |
